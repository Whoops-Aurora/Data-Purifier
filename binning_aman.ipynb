# %% [markdown]
# # EDA COURSE PROJECT

# %% [markdown]
# # Data science student championship

# %% [markdown]
# # Team Details

# %%
data=[{'Name':'Amaan Khan','Roll No':240,'USN':'01FE21BCS212'},{'Name':'Adwait S','Roll No':241,'USN':'01FE21BCS222'},{'Name':'Poorva Khatawate','Roll No':248,'USN':'01FE21BCS302'},
     {'Name':'Shubhashri Shetty','Roll No':249,'USN':'01FE21BCS143'}]
details=pd.DataFrame(data)
details
# Out:
#                 Name  Roll No           USN
# 0         Amaan Khan      240  01FE21BCS212
# 1           Adwait S      241  01FE21BCS222
# 2   Poorva Khatawate      248  01FE21BCS302
# 3  Shubhashri Shetty      249  01FE21BCS143

# %%
import pandas as pd
import numpy as np

# %%
India_test=pd.read_csv('India_test.csv')

# %%
India_train=pd.read_csv('India_train.csv')
submission=pd.read_csv('submission.csv')
USA_train=pd.read_csv('USA_train.csv')
USA_test=pd.read_csv('USA_test.csv')
USA_Commodity_prices=pd.read_csv('USA_Commodity_prices.csv')

# %%
India_soil_rainfall_30years=pd.read_csv('India_soil_rainfall_30years.csv')

# %%
India_train
# Out:
#       Year      State Name      Dist Name  COTTON AREA (1000 ha)  \
# 0     1990  Andhra Pradesh     Srikakulam                    0.0
# 1     1990  Andhra Pradesh  Visakhapatnam                    7.0
# 2     1990  Andhra Pradesh  East Godavari                   49.0
# 3     1990  Andhra Pradesh  West Godavari                   26.0
# 4     1990  Andhra Pradesh        Krishna                  996.0
# ...    ...             ...            ...                    ...
# 4700  2006     West Bengal     Jalpaiguri                    0.0
# 4701  2006     West Bengal     Darjeeling                    0.0
# 4702  2006     West Bengal          Malda                    NaN
# 4703  2006     West Bengal    Cooch Behar                    0.0
# 4704  2006     West Bengal        Purulia                    0.0
#
#       COTTON PRODUCTION (1000 tons)  COTTON YIELD (Kg per ha)  \
# 0                               0.0                         0
# ...

# %%
India_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4705 entries, 0 to 4704
# Columns: 103 entries, Year to TOTAL PER HA OF GCA (Kg per ha)
# dtypes: float64(99), int64(2), object(2)
# memory usage: 3.7+ MB

# %%
India_train.describe()
# Out:
#               Year  COTTON AREA (1000 ha)  COTTON PRODUCTION (1000 tons)  \
# count  4705.000000            4438.000000                    4477.000000
# mean   1998.025292             655.725327                     501.854367
# std       4.893509            2294.044035                    1623.216667
# min    1990.000000              -9.000000                      -9.000000
# 25%    1994.000000               0.000000                       0.000000
# 50%    1998.000000               4.000000                       0.000000
# 75%    2002.000000             225.750000                     117.000000
# max    2006.000000           39702.000000                   22694.000000
#
#        COTTON YIELD (Kg per ha)  JANUARY PERCIPITATION (Millimeters)  \
# count               4705.000000                          4489.000000
# mean                1929.775133                            18.153555
# std                 4919.725762                            25.831879
# ...

# %%
India_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2476 entries, 0 to 2475
# Columns: 103 entries, Year to TOTAL PER HA OF GCA (Kg per ha)
# dtypes: float64(99), int64(2), object(2)
# memory usage: 1.9+ MB

# %%
India_train.describe()
# Out:
#               Year  COTTON AREA (1000 ha)  COTTON PRODUCTION (1000 tons)  \
# count  4705.000000            4438.000000                    4477.000000
# mean   1998.025292             655.725327                     501.854367
# std       4.893509            2294.044035                    1623.216667
# min    1990.000000              -9.000000                      -9.000000
# 25%    1994.000000               0.000000                       0.000000
# 50%    1998.000000               4.000000                       0.000000
# 75%    2002.000000             225.750000                     117.000000
# max    2006.000000           39702.000000                   22694.000000
#
#        COTTON YIELD (Kg per ha)  JANUARY PERCIPITATION (Millimeters)  \
# count               4705.000000                          4489.000000
# mean                1929.775133                            18.153555
# std                 4919.725762                            25.831879
# ...

# %%
USA_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Year                                              400 non-null    int64
#  1   State                                             380 non-null    object
#  2   Planted (1000 Acres)                              386 non-null    object
#  3   Harvested (1000 Acres)                            385 non-null    object
#  4   Yield (Pounds/ Harvested Area)                    400 non-null    int64
#  5   Average Temperature Value                         366 non-null    float64
#  6   Average Temperature Anomaly                       379 non-null    float64
#  7   Maximum Temperature Value                         368 non-null    float64
#  8   Maximum Temperature Anomaly                       379 non-null    float64
# ...

# %%
USA_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560 entries, 0 to 559
# Data columns (total 25 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Year                                              560 non-null    int64
#  1   State                                             528 non-null    object
#  2   Planted (1000 Acres)                              537 non-null    object
#  3   Harvested (1000 Acres)                            540 non-null    object
#  4   Yield (Pounds/ Harvested Area)                    560 non-null    int64
#  5   Average Temperature Value                         532 non-null    float64
#  6   Average Temperature Anomaly                       529 non-null    float64
#  7   Maximum Temperature Value                         538 non-null    float64
#  8   Maximum Temperature Anomaly                       527 non-null    float64
# ...

# %%
USA_test.describe()
# Out:
#               Year  Yield (Pounds/ Harvested Area)  Average Temperature Value  \
# count   400.000000                           400.0                 366.000000
# mean   2012.500000                             0.0                  62.814822
# std       5.773503                             0.0                   5.282566
# min    2003.000000                             0.0                  50.566667
# 25%    2007.750000                             0.0                  58.806250
# 50%    2012.500000                             0.0                  62.895833
# 75%    2017.250000                             0.0                  66.616667
# max    2022.000000                             0.0                  77.183333
#
#        Average Temperature Anomaly  Maximum Temperature Value  \
# count                   379.000000                 368.000000
# mean                      3.054617                  74.599207
# std                       1.595499                   5.080334
# ...

# %%
USA_train.describe()
# Out:
#               Year  Yield (Pounds/ Harvested Area)  Average Temperature Value  \
# count   560.000000                      560.000000                 532.000000
# mean   1988.500000                      538.010714                  61.607221
# std       8.084969                      321.951007                   5.325217
# min    1975.000000                        0.000000                  50.108333
# 25%    1981.750000                      370.000000                  57.487500
# 50%    1988.500000                      547.000000                  61.475000
# 75%    1995.250000                      716.000000                  65.400000
# max    2002.000000                     1470.000000                  75.550000
#
#        Average Temperature Anomaly  Maximum Temperature Value  \
# count                   529.000000                 538.000000
# mean                      2.016005                  73.572878
# std                       1.521716                   5.155871
# ...

# %%
India_soil_rainfall_30years.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 17 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   State Name                               313 non-null    object
#  1   Dist Name                                313 non-null    object
#  2   SOIL TYPE PERCENT (Percent)              310 non-null    object
#  3   Year_Rainfall                            313 non-null    object
#  4   JANUARY NORMAL RAINFALL (Millimeters)    313 non-null    int64
#  5   FEBRUARY NORMAL RAINFALL (Millimeters)   313 non-null    int64
#  6   MARCH NORMAL RAINFALL (Millimeters)      313 non-null    int64
#  7   APRIL NORMAL RAINFALL (Millimeters)      313 non-null    int64
#  8   MAY NORMAL RAINFALL (Millimeters)        313 non-null    int64
#  9   JUNE NORMAL RAINFALL (Millimeters)       313 non-null    int64
# ...

# %%
India_soil_rainfall_30years.describe()
# Out:
#        JANUARY NORMAL RAINFALL (Millimeters)  \
# count                             313.000000
# mean                               19.319489
# std                                19.869288
# min                                -1.000000
# 25%                                 6.000000
# 50%                                14.000000
# 75%                                24.000000
# max                               146.000000
#
#        FEBRUARY NORMAL RAINFALL (Millimeters)  \
# count                              313.000000
# mean                                17.485623
# std                                 18.544661
# min                                 -1.000000
# 25%                                  5.000000
# 50%                                 14.000000
# 75%                                 22.000000
# max                                141.000000
#
#        MARCH NORMAL RAINFALL (Millimeters)  \
# count                           313.000000
# ...

# %%
India_train.isnull().sum()
# Out:
# Year                                  0
# State Name                            0
# Dist Name                             0
# COTTON AREA (1000 ha)               267
# COTTON PRODUCTION (1000 tons)       228
#                                    ...
# POTASH PER HA OF NCA (Kg per ha)    256
# POTASH PER HA OF GCA (Kg per ha)    238
# TOTAL CONSUMPTION (tons)            265
# TOTAL PER HA OF NCA (Kg per ha)     262
# TOTAL PER HA OF GCA (Kg per ha)     231
# Length: 103, dtype: int64

# %%
avg_march=India_train['MARCH MINIMUM (Centigrate)'].astype('float').mean(axis=0)

# %%
India_train['MARCH MINIMUM (Centigrate)'].replace(np.nan,avg_march,inplace=True)

# %%
India_train['MARCH MINIMUM (Centigrate)'].isnull().sum()
# Out:
# 0

# %%
avg_march1=India_train['APRIL MINIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['APRIL MINIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['APRIL MINIMUM (Centigrate)']
# Out:
# 0       29.640000
# 1       26.560000
# 2       27.930000
# 3       26.570000
# 4       29.090000
#           ...
# 4700    25.290000
# 4701    19.760000
# 4702    23.440000
# 4703    25.350000
# 4704    24.358252
# Name: APRIL MINIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['MAY MINIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['MAY MINIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['MAY MINIMUM (Centigrate)']
# Out:
# 0       29.24
# 1       23.87
# 2       26.25
# 3       25.82
# 4       27.30
#         ...
# 4700    25.63
# 4701    24.06
# 4702    27.34
# 4703    26.35
# 4704    28.20
# Name: MAY MINIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['JUNE MINIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['JUNE MINIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['JUNE MINIMUM (Centigrate)']
# Out:
# 0       28.38
# 1       27.06
# 2       28.28
# 3       29.05
# 4       26.43
#         ...
# 4700    28.84
# 4701    24.56
# 4702    28.09
# 4703    29.39
# 4704    27.19
# Name: JUNE MINIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['JULY MINIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['JULY MINIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['JULY MINIMUM (Centigrate)']
# Out:
# 0       26.31
# 1       24.27
# 2       25.81
# 3       26.62
# 4       27.73
#         ...
# 4700    29.19
# 4701    23.95
# 4702    30.36
# 4703    27.32
# 4704    25.76
# Name: JULY MINIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['AUGUST MINIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['AUGUST MINIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['AUGUST MINIMUM (Centigrate)']
# Out:
# 0       29.71
# 1       23.67
# 2       25.98
# 3       26.72
# 4       25.93
#         ...
# 4700    27.15
# 4701    26.64
# 4702    28.47
# 4703    30.46
# 4704    27.22
# Name: AUGUST MINIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['SEPTEMBER MINIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['SEPTEMBER MINIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['SEPTEMBER MINIMUM (Centigrate)']
# Out:
# 0       28.53
# 1       23.67
# 2       27.97
# 3       28.69
# 4       27.04
#         ...
# 4700    27.94
# 4701    25.43
# 4702    26.98
# 4703    26.52
# 4704    28.91
# Name: SEPTEMBER MINIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['OCTOBER MINIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['OCTOBER MINIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['OCTOBER MINIMUM (Centigrate)']
# Out:
# 0       25.52
# 1       23.76
# 2       25.37
# 3       24.28
# 4       24.47
#         ...
# 4700    26.33
# 4701    22.91
# 4702    24.31
# 4703    23.77
# 4704    26.24
# Name: OCTOBER MINIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['NOVEMBER MINIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['NOVEMBER MINIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['NOVEMBER MINIMUM (Centigrate)']
# Out:
# 0       23.100000
# 1       22.590000
# 2       21.980000
# 3       24.740000
# 4       23.660000
#           ...
# 4700    20.910000
# 4701    16.400000
# 4702    17.474395
# 4703    20.930000
# 4704    22.290000
# Name: NOVEMBER MINIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['DECEMBER MINIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['DECEMBER MINIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['DECEMBER MINIMUM (Centigrate)']
# Out:
# 0       20.770000
# 1       18.990000
# 2       21.070000
# 3       22.090000
# 4       14.017331
#           ...
# 4700    16.620000
# 4701    12.370000
# 4702    14.880000
# 4703    14.017331
# 4704    17.440000
# Name: DECEMBER MINIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['JANUARY MAXIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['JANUARY MAXIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['JANUARY MAXIMUM (Centigrate)']
# Out:
# 0       32.01
# 1       29.39
# 2       31.98
# 3       33.05
# 4       32.77
#         ...
# 4700    29.26
# 4701    25.09
# 4702    31.23
# 4703    30.44
# 4704    30.05
# Name: JANUARY MAXIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['FEBRUARY MAXIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['FEBRUARY MAXIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['FEBRUARY MAXIMUM (Centigrate)']
# Out:
# 0       30.91
# 1       32.09
# 2       30.63
# 3       33.72
# 4       35.01
#         ...
# 4700    31.79
# 4701    27.05
# 4702    32.50
# 4703    32.45
# 4704    34.84
# Name: FEBRUARY MAXIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['FEBRUARY MAXIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['FEBRUARY MAXIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['FEBRUARY MAXIMUM (Centigrate)']
# Out:
# 0       30.91
# 1       32.09
# 2       30.63
# 3       33.72
# 4       35.01
#         ...
# 4700    31.79
# 4701    27.05
# 4702    32.50
# 4703    32.45
# 4704    34.84
# Name: FEBRUARY MAXIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['MARCH MAXIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['MARCH MAXIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['MARCH MAXIMUM (Centigrate)']
# Out:
# 0       33.03
# 1       31.59
# 2       36.76
# 3       35.69
# 4       38.51
#         ...
# 4700    35.15
# 4701    28.18
# 4702    36.65
# 4703    34.67
# 4704    37.90
# Name: MARCH MAXIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['APRIL MAXIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['APRIL MAXIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['APRIL MAXIMUM (Centigrate)']
# Out:
# 0       34.400000
# 1       37.100000
# 2       38.030000
# 3       39.070000
# 4       37.960000
#           ...
# 4700    35.270000
# 4701    38.207666
# 4702    38.040000
# 4703    33.550000
# 4704    38.207666
# Name: APRIL MAXIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['MAY MAXIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['MAY MAXIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['MAY MAXIMUM (Centigrate)']
# Out:
# 0       34.37
# 1       35.84
# 2       37.12
# 3       39.25
# 4       37.15
#         ...
# 4700    34.94
# 4701    30.18
# 4702    36.05
# 4703    34.74
# 4704    43.06
# Name: MAY MAXIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['JUNE MAXIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['JUNE MAXIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['JUNE MAXIMUM (Centigrate)']
# Out:
# 0       33.44
# 1       34.57
# 2       34.16
# 3       38.52
# 4       37.22
#         ...
# 4700    34.82
# 4701    31.38
# 4702    34.11
# 4703    35.34
# 4704    37.41
# Name: JUNE MAXIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['JULY MAXIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['JULY MAXIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['JULY MAXIMUM (Centigrate)']
# Out:
# 0       31.56000
# 1       33.64397
# 2       31.30000
# 3       33.50000
# 4       34.09000
#           ...
# 4700    33.70000
# 4701    31.38000
# 4702    35.75000
# 4703    35.62000
# 4704    33.88000
# Name: JULY MAXIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['AUGUST MAXIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['AUGUST MAXIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['AUGUST MAXIMUM (Centigrate)']
# Out:
# 0       34.52000
# 1       32.39000
# 2       33.41000
# 3       33.38000
# 4       35.91000
#           ...
# 4700    32.85205
# 4701    30.93000
# 4702    34.33000
# 4703    33.55000
# 4704    33.46000
# Name: AUGUST MAXIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['SEPTEMBER MAXIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['SEPTEMBER MAXIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['SEPTEMBER MAXIMUM (Centigrate)']
# Out:
# 0       33.47
# 1       32.83
# 2       33.58
# 3       34.45
# 4       34.17
#         ...
# 4700    35.92
# 4701    29.24
# 4702    35.46
# 4703    35.21
# 4704    35.95
# Name: SEPTEMBER MAXIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['OCTOBER MAXIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['OCTOBER MAXIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['OCTOBER MAXIMUM (Centigrate)']
# Out:
# 0       33.64
# 1       29.78
# 2       32.40
# 3       31.36
# 4       33.77
#         ...
# 4700    33.31
# 4701    28.56
# 4702    32.08
# 4703    33.50
# 4704    35.15
# Name: OCTOBER MAXIMUM (Centigrate), Length: 4705, dtype: float64

# %%
avg_march1=India_train['NOVEMBER MAXIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['NOVEMBER MAXIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['NOVEMBER MAXIMUM (Centigrate)']
# Out:
# 0       31.77
# 1       27.94
# 2       32.49
# 3       32.88
# 4       32.57
#         ...
# 4700    28.28
# 4701    26.72
# 4702    31.02
# 4703    31.41
# 4704    30.84
# Name: NOVEMBER MAXIMUM (Centigrate), Length: 4705, dtype: float64

# %%
India_train.isnull().sum()
# Out:
# Year                                  0
# State Name                            0
# Dist Name                             0
# COTTON AREA (1000 ha)               267
# COTTON PRODUCTION (1000 tons)       228
#                                    ...
# POTASH PER HA OF NCA (Kg per ha)    256
# POTASH PER HA OF GCA (Kg per ha)    238
# TOTAL CONSUMPTION (tons)            265
# TOTAL PER HA OF NCA (Kg per ha)     262
# TOTAL PER HA OF GCA (Kg per ha)     231
# Length: 103, dtype: int64

# %%
avg_march1=India_train['NOVEMBER MAXIMUM (Centigrate)'].astype('float').mean(axis=0)
India_train['NOVEMBER MAXIMUM (Centigrate)'].replace(np.nan,avg_march1,inplace=True)
India_train['NOVEMBER MAXIMUM (Centigrate)']
India_train.isnull().sum()
# Out:
# Year                                  0
# State Name                            0
# Dist Name                             0
# COTTON AREA (1000 ha)               267
# COTTON PRODUCTION (1000 tons)       228
#                                    ...
# POTASH PER HA OF NCA (Kg per ha)    256
# POTASH PER HA OF GCA (Kg per ha)    238
# TOTAL CONSUMPTION (tons)            265
# TOTAL PER HA OF NCA (Kg per ha)     262
# TOTAL PER HA OF GCA (Kg per ha)     231
# Length: 103, dtype: int64

# %% [markdown]
# # Data Normalization

# %%
India_train['DECEMBER MAXIMUM (Centigrate)']=India_train['DECEMBER MAXIMUM (Centigrate)'].astype(float, copy=True)
India_train['JANUARY WATER DEFICIT (Millimeters)']=India_train['JANUARY WATER DEFICIT (Millimeters)'].astype(float, copy=True)
India_train['FEBRUARY WATER DEFICIT (Millimeters)']=India_train['FEBRUARY WATER DEFICIT (Millimeters)'].astype(float, copy=True)
India_train['MARCH WATER DEFICIT (Millimeters)']=India_train['MARCH WATER DEFICIT (Millimeters)'].astype(float, copy=True)
India_train['APRIL WATER DEFICIT (Millimeters)']=India_train['APRIL WATER DEFICIT (Millimeters)'].astype(float, copy=True)
India_train['MAY WATER DEFICIT (Millimeters)']=India_train['MAY WATER DEFICIT (Millimeters)'].astype(float, copy=True)
India_train['JUNE WATER DEFICIT (Millimeters)']=India_train['JUNE WATER DEFICIT (Millimeters)'].astype(float, copy=True)
India_train['JULY WATER DEFICIT (Millimeters)']=India_train['JULY WATER DEFICIT (Millimeters)'].astype(float, copy=True)
India_train['AUGUST WATER DEFICIT (Millimeters)']=India_train['AUGUST WATER DEFICIT (Millimeters)'].astype(float, copy=True)
India_train['OCTOBER WATER DEFICIT (Millimeters)']=India_train['OCTOBER WATER DEFICIT (Millimeters)'].astype(float, copy=True)
India_train['NOVEMBER WATER DEFICIT (Millimeters)']=India_train['NOVEMBER WATER DEFICIT (Millimeters)'].astype(float, copy=True)
India_train['DECEMBER WATER DEFICIT (Millimeters)']=India_train['DECEMBER WATER DEFICIT (Millimeters)'].astype(float, copy=True)
India_train['JANUARY ACTUAL (Millimeters)']=India_train['JANUARY ACTUAL (Millimeters)'].astype(float, copy=True)
India_train['FEBRUARY ACTUAL (Millimeters)']=India_train['FEBRUARY ACTUAL (Millimeters)'].astype(float, copy=True)
India_train['MARCH ACTUAL (Millimeters)']=India_train['MARCH ACTUAL (Millimeters)'].astype(float, copy=True)
India_train['APRIL ACTUAL (Millimeters)']=India_train['APRIL ACTUAL (Millimeters)'].astype(float, copy=True)
India_train['MAY ACTUAL (Millimeters)']=India_train['MAY ACTUAL (Millimeters)'].astype(float, copy=True)
India_train['JUNE ACTUAL (Millimeters)']=India_train['JUNE ACTUAL (Millimeters)'].astype(float, copy=True)
India_train['JULY ACTUAL (Millimeters)']=India_train['JULY ACTUAL (Millimeters)'].astype(float, copy=True)
India_train['AUGUST ACTUAL (Millimeters)']=India_train['AUGUST ACTUAL (Millimeters)'].astype(float, copy=True)
India_train['SEPTEMBER ACTUAL (Millimeters)']=India_train['SEPTEMBER ACTUAL (Millimeters)'].astype(float, copy=True)

India_train
# Out:
#       Year      State Name      Dist Name  COTTON AREA (1000 ha)  \
# 0     1990  Andhra Pradesh     Srikakulam                    0.0
# 1     1990  Andhra Pradesh  Visakhapatnam                    7.0
# 2     1990  Andhra Pradesh  East Godavari                   49.0
# 3     1990  Andhra Pradesh  West Godavari                   26.0
# 4     1990  Andhra Pradesh        Krishna                  996.0
# ...    ...             ...            ...                    ...
# 4700  2006     West Bengal     Jalpaiguri                    0.0
# 4701  2006     West Bengal     Darjeeling                    0.0
# 4702  2006     West Bengal          Malda                    NaN
# 4703  2006     West Bengal    Cooch Behar                    0.0
# 4704  2006     West Bengal        Purulia                    0.0
#
#       COTTON PRODUCTION (1000 tons)  COTTON YIELD (Kg per ha)  \
# 0                               0.0                         0
# ...

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
import numpy as np
plt.pyplot.hist(India_train['MARCH MINIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('MARCH MINIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('MARCH MINIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'MARCH MINIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['APRIL MINIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('APRIL MINIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('APRIL MINIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'APRIL MINIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['MAY MINIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('MAY MINIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('MAY MINIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'MAY MINIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['JUNE MINIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('JUNE MINIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('JUNE MINIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'JUNE MINIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['JULY MINIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('JULY MINIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('JULY MINIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'JULY MINIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['AUGUST MINIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('AUGUST MINIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('AUGUST MINIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'AUGUST MINIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['SEPTEMBER MINIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('SEPTEMBER MINIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('SEPTEMBER MINIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'SEPTEMBER MINIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['OCTOBER MINIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('OCTOBER MINIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('OCTOBER MINIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'OCTOBER MINIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['NOVEMBER MINIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('NOVEMBER MINIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('NOVEMBER MINIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'NOVEMBER MINIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['DECEMBER MINIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('DECEMBER MINIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('DECEMBER MINIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'DECEMBER MINIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['JANUARY MAXIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('JANUARY MAXIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('JANUARY MAXIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'JANUARY MAXIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['FEBRUARY MAXIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('FEBRUARY MAXIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('FEBRUARY MAXIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'FEBRUARY MAXIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['MARCH MAXIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('MARCH MAXIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('MARCH MAXIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'MARCH MAXIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['APRIL MAXIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('APRIL MAXIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('APRIL MAXIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'APRIL MAXIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['MAY MAXIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('MAY MAXIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('MAY MAXIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'MAY MAXIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['JUNE MAXIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('JUNE MAXIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('JUNE MAXIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'JUNE MAXIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['JULY MAXIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('JULY MAXIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('JULY MAXIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'JULY MAXIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['AUGUST MAXIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('AUGUST MAXIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('AUGUST MAXIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'AUGUST MAXIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['SEPTEMBER MAXIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('SEPTEMBER MAXIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('SEPTEMBER MAXIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'SEPTEMBER MAXIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['OCTOBER MAXIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('OCTOBER MAXIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('OCTOBER MAXIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'OCTOBER MAXIMUM (Centigrate)')

# %%
plt.pyplot.hist(India_train['NOVEMBER MAXIMUM (Centigrate)'],color='black')

# set x/y labels and plot title
plt.pyplot.xlabel('NOVEMBER MAXIMUM (Centigrate)')
plt.pyplot.ylabel("count")
plt.pyplot.title('NOVEMBER MAXIMUM (Centigrate)')
# Out:
# Text(0.5, 1.0, 'NOVEMBER MAXIMUM (Centigrate)')

# %%
bins = np.linspace(min(India_train['MARCH MINIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins1= np.linspace(min(India_train['APRIL MINIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins2= np.linspace(min(India_train['MAY MINIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins3 = np.linspace(min(India_train['JUNE MINIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins4= np.linspace(min(India_train['JULY MINIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins5= np.linspace(min(India_train['AUGUST MINIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins6= np.linspace(min(India_train['SEPTEMBER MINIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins7= np.linspace(min(India_train['OCTOBER MINIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins8= np.linspace(min(India_train['NOVEMBER MINIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins9= np.linspace(min(India_train['DECEMBER MINIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins10= np.linspace(min(India_train['JANUARY MAXIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins11= np.linspace(min(India_train['FEBRUARY MAXIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins12= np.linspace(min(India_train['MARCH MAXIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins13= np.linspace(min(India_train['APRIL MAXIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins14= np.linspace(min(India_train['MAY MAXIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins15= np.linspace(min(India_train['JUNE MAXIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins16= np.linspace(min(India_train['JULY MAXIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins17= np.linspace(min(India_train['AUGUST MAXIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins18= np.linspace(min(India_train['SEPTEMBER MAXIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins19= np.linspace(min(India_train['OCTOBER MAXIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)
bins20= np.linspace(min(India_train['NOVEMBER MAXIMUM (Centigrate)']), max(India_train['MARCH MINIMUM (Centigrate)']), 4)

# %%
group_names = ['Low', 'Medium', 'High']

# %%
India_train['MARCH MINIMUM (Centigrate)-binned'] = pd.cut(India_train['MARCH MINIMUM (Centigrate)'], bins, labels=group_names, include_lowest=True)
India_train['APRIL MINIMUM (Centigrate)-binned'] = pd.cut(India_train['APRIL MINIMUM (Centigrate)'], bins1, labels=group_names, include_lowest=True)
India_train['MAY MINIMUM (Centigrate)-binned'] = pd.cut(India_train['MAY MINIMUM (Centigrate)'], bins2, labels=group_names, include_lowest=True)
India_train['JUNE MINIMUM (Centigrate)-binned'] = pd.cut(India_train['JUNE MINIMUM (Centigrate)'], bins3, labels=group_names, include_lowest=True)
India_train['JULY MINIMUM (Centigrate)-binned'] = pd.cut(India_train['JULY MINIMUM (Centigrate)'], bins4, labels=group_names, include_lowest=True)
India_train['AUGUST MINIMUM (Centigrate)-binned'] = pd.cut(India_train['AUGUST MINIMUM (Centigrate)'], bins5, labels=group_names, include_lowest=True)
India_train['SEPTEMBER MINIMUM (Centigrate)-binned'] = pd.cut(India_train['SEPTEMBER MINIMUM (Centigrate)'], bins6, labels=group_names, include_lowest=True)
India_train['OCTOBER MINIMUM (Centigrate)-binned'] = pd.cut(India_train['OCTOBER MINIMUM (Centigrate)'], bins7, labels=group_names, include_lowest=True)
India_train['NOVEMBER MINIMUM (Centigrate)-binned'] = pd.cut(India_train['NOVEMBER MINIMUM (Centigrate)'], bins8, labels=group_names, include_lowest=True)
India_train['DECEMBER MINIMUM (Centigrate)-binned'] = pd.cut(India_train['DECEMBER MINIMUM (Centigrate)'], bins9, labels=group_names, include_lowest=True)
India_train['JANUARY MAXIMUM (Centigrate)-binned'] = pd.cut(India_train['JANUARY MAXIMUM (Centigrate)'], bins10, labels=group_names, include_lowest=True)
India_train['FEBRUARY MAXIMUM (Centigrate)-binned'] = pd.cut(India_train['FEBRUARY MAXIMUM (Centigrate)'], bins11, labels=group_names, include_lowest=True)
India_train['MARCH MAXIMUM (Centigrate)-binned'] = pd.cut(India_train['MARCH MAXIMUM (Centigrate)'], bins12, labels=group_names, include_lowest=True)
India_train['APRIL MAXIMUM (Centigrate)-binned'] = pd.cut(India_train['APRIL MAXIMUM (Centigrate)'], bins13, labels=group_names, include_lowest=True)
India_train['MAY MAXIMUM (Centigrate)-binned'] = pd.cut(India_train['MAY MAXIMUM (Centigrate)'], bins14, labels=group_names, include_lowest=True)
India_train['JUNE MAXIMUM (Centigrate)-binned'] = pd.cut(India_train['JUNE MAXIMUM (Centigrate)'], bins15, labels=group_names, include_lowest=True)
India_train['JULY MAXIMUM (Centigrate)-binned'] = pd.cut(India_train['JULY MAXIMUM (Centigrate)'], bins16, labels=group_names, include_lowest=True)
India_train['AUGUST MAXIMUM (Centigrate)-binned'] = pd.cut(India_train['AUGUST MAXIMUM (Centigrate)'], bins17, labels=group_names, include_lowest=True)
India_train['SEPTEMBER MAXIMUM (Centigrate)-binned'] = pd.cut(India_train['SEPTEMBER MAXIMUM (Centigrate)'], bins18, labels=group_names, include_lowest=True)
India_train['OCTOBER MAXIMUM (Centigrate)-binned'] = pd.cut(India_train['OCTOBER MAXIMUM (Centigrate)'], bins19, labels=group_names, include_lowest=True)
India_train['NOVEMBER MAXIMUM (Centigrate)-binned'] = pd.cut(India_train['NOVEMBER MAXIMUM (Centigrate)'], bins20, labels=group_names, include_lowest=True)

# %%
India_train[['MARCH MINIMUM (Centigrate)','MARCH MINIMUM (Centigrate)-binned']].head(20)

India_train["MARCH MINIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      4515
# Medium     135
# Low         55
# Name: MARCH MINIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['APRIL MINIMUM (Centigrate)','APRIL MINIMUM (Centigrate)-binned']].head(20)
India_train["APRIL MINIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      4475
# Medium      90
# Low         70
# Name: APRIL MINIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['MAY MINIMUM (Centigrate)','MAY MINIMUM (Centigrate)-binned']].head(20)
India_train["MAY MINIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      3257
# Medium      92
# Low         42
# Name: MAY MINIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['JUNE MINIMUM (Centigrate)','JUNE MINIMUM (Centigrate)-binned']].head(20)
India_train["JUNE MINIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      2999
# Medium      88
# Low         54
# Name: JUNE MINIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['JULY MINIMUM (Centigrate)','JULY MINIMUM (Centigrate)-binned']].head(20)
India_train["JULY MINIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      3911
# Medium     106
# Low         66
# Name: JULY MINIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['AUGUST MINIMUM (Centigrate)','AUGUST MINIMUM (Centigrate)-binned']].head(20)
India_train["AUGUST MINIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      4192
# Medium     110
# Low         50
# Name: AUGUST MINIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['SEPTEMBER MINIMUM (Centigrate)','SEPTEMBER MINIMUM (Centigrate)-binned']].head(20)
India_train["SEPTEMBER MINIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      4463
# Medium     109
# Low         46
# Name: SEPTEMBER MINIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['OCTOBER MINIMUM (Centigrate)','APRIL MINIMUM (Centigrate)-binned']].head(20)
India_train["OCTOBER MINIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      4467
# Medium     160
# Low         78
# Name: OCTOBER MINIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['NOVEMBER MINIMUM (Centigrate)','APRIL MINIMUM (Centigrate)-binned']].head(20)
India_train["NOVEMBER MINIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      3734
# Medium     886
# Low         85
# Name: NOVEMBER MINIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['DECEMBER MINIMUM (Centigrate)','APRIL MINIMUM (Centigrate)-binned']].head(20)
India_train["DECEMBER MINIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      2954
# Medium    1673
# Low         78
# Name: DECEMBER MINIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['JANUARY MAXIMUM (Centigrate)','JANUARY MAXIMUM (Centigrate)-binned']].head(20)
India_train["JANUARY MAXIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      2976
# Medium     113
# Low         38
# Name: JANUARY MAXIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['FEBRUARY MAXIMUM (Centigrate)','FEBRUARY MAXIMUM (Centigrate)-binned']].head(20)
India_train["FEBRUARY MAXIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      1497
# Medium      89
# Low         43
# Name: FEBRUARY MAXIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['MARCH MAXIMUM (Centigrate)','MARCH MAXIMUM (Centigrate)-binned']].head(20)
India_train["MARCH MAXIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      281
# Medium     89
# Low        32
# Name: MARCH MAXIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['APRIL MAXIMUM (Centigrate)','APRIL MAXIMUM (Centigrate)-binned']].head(20)
India_train["APRIL MAXIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      114
# Medium     76
# Low        31
# Name: APRIL MAXIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['MAY MAXIMUM (Centigrate)','MAY MAXIMUM (Centigrate)-binned']].head(20)
India_train["MAY MAXIMUM (Centigrate)-binned"].value_counts()
# Out:
# Medium    82
# High      60
# Low       24
# Name: MAY MAXIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['JUNE MAXIMUM (Centigrate)','JUNE MAXIMUM (Centigrate)-binned']].head(20) 
India_train["JUNE MAXIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      114
# Medium     76
# Low        25
# Name: JUNE MAXIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['JULY MAXIMUM (Centigrate)','JULY MAXIMUM (Centigrate)-binned']].head(20)
India_train["JULY MAXIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      365
# Medium     81
# Low        42
# Name: JULY MAXIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['AUGUST MAXIMUM (Centigrate)','AUGUST MAXIMUM (Centigrate)-binned']].head(20)
India_train["AUGUST MAXIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      383
# Medium     82
# Low        49
# Name: AUGUST MAXIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['SEPTEMBER MAXIMUM (Centigrate)','SEPTEMBER MAXIMUM (Centigrate)-binned']].head(20)
India_train["SEPTEMBER MAXIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      234
# Medium     84
# Low        40
# Name: SEPTEMBER MAXIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['OCTOBER MAXIMUM (Centigrate)','OCTOBER MAXIMUM (Centigrate)-binned']].head(20)
India_train["OCTOBER MAXIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      217
# Medium     81
# Low        48
# Name: OCTOBER MAXIMUM (Centigrate)-binned, dtype: int64

# %%
India_train[['NOVEMBER MAXIMUM (Centigrate)','NOVEMBER MAXIMUM (Centigrate)-binned']].head(20)
India_train["NOVEMBER MAXIMUM (Centigrate)-binned"].value_counts()
# Out:
# High      756
# Medium     88
# Low        42
# Name: NOVEMBER MAXIMUM (Centigrate)-binned, dtype: int64

# %% [markdown]
# # #Bins visualization
# Normally a histogram is used to represent bins visualisation

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, India_train["MARCH MINIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("MARCH MINIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("MARCH MINIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'MARCH MINIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["APRIL MINIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("APRIL MINIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("APRIL MINIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'APRIL MINIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["MAY MINIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("MAY MINIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("MAY MINIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'MAY MINIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["JUNE MINIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("JUNE MINIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("JUNE MINIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'JUNE MINIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["JULY MINIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("JULY MINIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("JULY MINIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'JULY MINIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["AUGUST MINIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("AUGUST MINIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("AUGUST MINIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'AUGUST MINIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["SEPTEMBER MINIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("SEPTEMBER MINIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("SEPTEMBER MINIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'SEPTEMBER MINIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["OCTOBER MINIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("OCTOBER MINIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("OCTOBER MINIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'OCTOBER MINIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["NOVEMBER MINIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("NOVEMBER MINIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("NOVEMBER MINIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'NOVEMBER MINIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["DECEMBER MINIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("DECEMBER MINIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("DECEMBER MINIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'DECEMBER MINIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["JANUARY MAXIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("JANUARY MAXIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("JANUARY MAXIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'JANUARY MAXIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["FEBRUARY MAXIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("FEBRUARY MAXIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("FEBRUARY MAXIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'FEBRUARY MAXIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["MARCH MAXIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("MARCH MAXIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("MARCH MAXIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'MARCH MAXIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["APRIL MAXIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("APRIL MAXIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("APRIL MAXIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'APRIL MAXIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["MAY MAXIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("MAY MAXIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("MAY MAXIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'MAY MAXIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["JUNE MAXIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("JUNE MAXIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("JULY MAXIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'JULY MAXIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["AUGUST MAXIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("AUGUST MAXIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("AUGUST MAXIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'AUGUST MAXIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["SEPTEMBER MAXIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("SEPTEMBER MAXIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("SEPTEMBER MAXIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'SEPTEMBER MAXIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["OCTOBER MAXIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("OCTOBER MAXIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("OCTOBER MAXIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'OCTOBER MAXIMUM (Centigrate) bins')

# %%
pyplot.bar(group_names, India_train["NOVEMBER MAXIMUM (Centigrate)-binned"].value_counts())
       
# set x/y labels and plot title
plt.pyplot.xlabel("NOVEMBER MAXIMUM (Centigrate)")
plt.pyplot.ylabel("count")
plt.pyplot.title("NOVEMBER MAXIMUM (Centigrate) bins")
# Out:
# Text(0.5, 1.0, 'NOVEMBER MAXIMUM (Centigrate) bins')
